# %%
import pandas as pd
import numpy as np
import mnist
import matplotlib.pyplot as plt

# %%
from utils import *
mnist.download()
digits, labels = mnist.extract_train()
display_digits_line(digits, labels, '', 48)
